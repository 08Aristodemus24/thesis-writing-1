# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download('https://www.kaggle.com/datasets/hijest/englishrussian-dictionary-for-machine-translate?resource=download')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: michaelcueva
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/hijest/englishrussian-dictionary-for-machine-translate
# ...
# 100%|██████████| 11.9M/11.9M [00:00<00:00, 57.2MB/s]

# %%
import pandas as pd
lines = pd.read_csv('englishrussian-dictionary-for-machine-translate/rus.txt', sep='\t', header=None)
lines
# Out:
#                                                         0  \
# 0                                                     Go.
# 1                                                     Go.
# 2                                                     Go.
# 3                                                     Hi.
# 4                                                     Hi.
# ...                                                   ...
# 363381  In today's world, we have to equip all our kid...
# 363382  Death is something that we're often discourage...
# 363383  At a moment when our economy is growing, our b...
# 363384  Since there are usually multiple websites on a...
# 363385  Doubtless there exists in this world precisely...
#
#                                                         1  \
# 0                                                   Марш!
# 1                                                    Иди.
# 2                                                  Идите.
# ...
