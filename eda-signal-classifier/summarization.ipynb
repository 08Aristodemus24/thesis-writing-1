# %%
import os
import pandas as pd
import re
import itertools
import json
import numpy as np

from utilities.loaders import load_results, summarize_results
from argparse import ArgumentParser

# %%
# load results.json 
results = load_results("gbt_results.json")
summarized_results = summarize_results(estimator_name="gbt", results=results)

# %%
summarized_results.shape
# Out:
# (10, 2)

# %%
summarized_results
# Out:
#                     n_estimators_200|learning_rate_0.01|max_depth_3|verbose_1  \
# mean_train_acc                                               0.930686
# mean_cross_acc                                               0.924063
# mean_train_prec                                              0.823476
# mean_cross_prec                                              0.601838
# mean_train_rec                                               0.385343
# mean_cross_rec                                               0.237054
# mean_train_f1                                                0.524952
# mean_cross_f1                                                0.302231
# mean_train_roc_auc                                           0.688102
# mean_cross_roc_auc                                           0.613133
#
#                     n_estimators_400|learning_rate_0.01|max_depth_3|verbose_1
# mean_train_acc                                               0.935951
# mean_cross_acc                                               0.924971
# mean_train_prec                                              0.825523
# mean_cross_prec                                              0.566705
# mean_train_rec                                               0.451037
# mean_cross_rec                                               0.251658
# mean_train_f1                                                0.583282
# mean_cross_f1                                                0.318331
# mean_train_roc_auc                                           0.720246
# mean_cross_roc_auc                                           0.619943

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
svm_hyper_param_config = {'C': 1, 'gamma': 0.001}
lr_hyper_param_config = {'C': 1}
rf_hyper_param_config = {'n_estimators': 200}
gbt_hyper_param_config = {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 3}
svm = SVC(**svm_hyper_param_config, verbose=1)
lr = LogisticRegression(**lr_hyper_param_config, verbose=1)
rf = RandomForestClassifier(**rf_hyper_param_config, verbose=1)
gbt = GradientBoostingClassifier(**gbt_hyper_param_config, verbose=1)
