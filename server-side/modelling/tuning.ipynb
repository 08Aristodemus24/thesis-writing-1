# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# navigate to root directory of current file in order to access other files relatively
# %cd /content/drive/MyDrive/Colab\ Notebooks/thesis-writing-1/eda-signal-classifier
# Out:
# /content/drive/MyDrive/Colab Notebooks/thesis-writing-1/eda-signal-classifier

# %%
# !python tuning_ml.py -m lr -pl taylor --mode tuning

# %%
# !python tuning_ml.py -m svm -pl taylor --mode tuning

# %%
# !python tuning_ml.py -m rf -pl taylor --mode tuning

# %%
# !python tuning_ml.py -m lr -pl hossain --mode tuning

# %%
# !python tuning_ml.py -m svm -pl hossain --mode tuning

# %%
# !python tuning_ml.py -m gbt -pl hossain --mode tuning

# %%
# !python tuning_dl.py -m lstm-cnn -pl jurado -lr 5e-5 --mode tuning
# Out:
# 2024-08-13 08:54:00.703646: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-13 08:54:00.723047: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-13 08:54:00.728940: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-13 08:54:00.742957: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python tuning_dl.py -m lstm-svm -pl cueva -lr 1e-3 -bs 1024 --mode tuning
